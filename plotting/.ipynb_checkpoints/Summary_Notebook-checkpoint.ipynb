# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import rcParams
import argparse

# Parser
my_folder = "Parameter_Analysis_Incast_64_64_100G"

# Creating the original DataFrame with the specified columns and adding the rows
df = pd.read_csv(my_folder + "/Summary.csv")
df = df[~((df["KMin"] == 20) & (df["DelayGain"] == 2))]
df = df[~((df["KMin"] == 50) & (df["DelayGain"] == 5))]


display(df)
# Out:
#               Algo  KMin  KMax  TargetRTT  FastDrop  FastIncrease  DoJitter  \
# 0          UEC BTS    20    80          0         0             0         0
# 1              NDP     0     0          0         0             0         0
# 2    UEC Version A    20    80         20         0             1         0
# 4    UEC Version A    20    80         20         0             1         0
# 5    UEC Version A    20    80         20         0             0         0
# ..             ...   ...   ...        ...       ...           ...       ...
# 187  UEC Version A    50    80         50         1             0         1
# 188  UEC Version A    50    80         50         1             0         1
# 190  UEC Version A    50    80         50         1             0         0
# 191  UEC Version A    50    80         50         1             0         0
# 192  UEC Version A    50    80         50         1             0         0
#
# ...

# %%
def run_comparison(df, filtering_on, possible_value_1, possible_value_2, possible_value_3 = None):
    # Columns
    all_options = ["Algo", "KMin", "FastDrop", "FastIncrease", "DoJitter",  "DoExpGain", "DelayGain"]
    all_options.remove(filtering_on)
    
    # Remove Other Algos
    removed_row = df[df["Algo"] == "NDP"].iloc[0]
    completion_time_ndp = removed_row["CompletionTime(us)"]

    #removed_row = df[df["Algo"] == "UEC BTS"].iloc[0]
    #completion_time_bts = removed_row["CompletionTime(us)"]

    #removed_row = df[df["Algo"] == "STrack"].iloc[0]
    #completion_time_strack = removed_row["CompletionTime(us)"]
    lowest_completion_time = df["CompletionTime(us)"].min()
    max_completion_time = df["CompletionTime(us)"].max()
    
    
    upper_limit = completion_time_ndp + completion_time_ndp * 0.05
    #for index, row in df.iterrows():
        #if int(df["CompletionTime(us)"][index]) > upper_limit:
            #print(row.loc["CompletionTime(us)"])
            #print("df = df[~((df['KMin'] == {}) & (df['FastDrop'] == {})  & (df['FastIncrease'] == {})  & (df['Algo'] == \'{}\') & (df['DoJitter'] == {})  & (df['DoExpGain'] == {})  & (df['DelayGain'] == {}))]".format(row.loc["KMin"], row.loc["FastDrop"], row.loc["FastIncrease"], row.loc["Algo"], row.loc["DoJitter"], row.loc["DoExpGain"], row.loc["DelayGain"]))
    # Add Better Legend and Improve Naming for readability
    df["X_Label"] = df[all_options].astype(str).agg(' '.join, axis=1)
    if (filtering_on == "KMin"):
        df["FastIncrease"] = "FI:" + df["FastIncrease"].astype(str)
        df["DoJitter"] = "J:" + df["DoJitter"].astype(str)
        df["DoExpGain"] = "E:" + df["DoExpGain"].astype(str)
        df["DelayGain"] = "D:" + df["DelayGain"].astype(str)
        df["FastDrop"] = "FD:" + df["FastDrop"].astype(str)
    elif (filtering_on == "FastIncrease"):
        df["KMin"] = "K:" + df["KMin"].astype(str)
        df["DoJitter"] = "J:" + df["DoJitter"].astype(str)
        df["DoExpGain"] = "E:" + df["DoExpGain"].astype(str)
        df["DelayGain"] = "D:" + df["DelayGain"].astype(str)
        df["FastDrop"] = "FD:" + df["FastDrop"].astype(str)
    elif (filtering_on == "DoJitter"):
        df["KMin"] = "K:" + df["KMin"].astype(str)
        df["FastIncrease"] = "FI:" + df["FastIncrease"].astype(str)
        df["DoExpGain"] = "E:" + df["DoExpGain"].astype(str)
        df["DelayGain"] = "D:" + df["DelayGain"].astype(str)
        df["FastDrop"] = "FD:" + df["FastDrop"].astype(str)
    elif (filtering_on == "DoExpGain"):
        df["KMin"] = "K:" + df["KMin"].astype(str)
        df["FastIncrease"] = "FI:" + df["FastIncrease"].astype(str)
        df["DoJitter"] = "J:" + df["DoJitter"].astype(str)
        df["DelayGain"] = "D:" + df["DelayGain"].astype(str)
        df["FastDrop"] = "FD:" + df["FastDrop"].astype(str)
    elif (filtering_on == "DelayGain"):
        df["KMin"] = "K:" + df["KMin"].astype(str)
        df["FastIncrease"] = "FI:" + df["FastIncrease"].astype(str)
        df["DoJitter"] = "J:" + df["DoJitter"].astype(str)
        df["DoExpGain"] = "E:" + df["DoExpGain"].astype(str)
        df["FastDrop"] = "FD:" + df["FastDrop"].astype(str)
    elif (filtering_on == "FastDrop"):
        df["KMin"] = "K:" + df["KMin"].astype(str)
        df["FastIncrease"] = "FI:" + df["FastIncrease"].astype(str)
        df["DoJitter"] = "J:" + df["DoJitter"].astype(str)
        df["DoExpGain"] = "E:" + df["DoExpGain"].astype(str)
        df["DelayGain"] = "D:" + df["DelayGain"].astype(str)
    elif (filtering_on == "Algo"):
        df["KMin"] = "K:" + df["KMin"].astype(str)
        df["FastIncrease"] = "FI:" + df["FastIncrease"].astype(str)
        df["DoJitter"] = "J:" + df["DoJitter"].astype(str)
        df["DoExpGain"] = "E:" + df["DoExpGain"].astype(str)
        df["DelayGain"] = "D:" + df["DelayGain"].astype(str)
        df["FastDrop"] = "FD:" + df["FastDrop"].astype(str)
        
    df["Algo"] = df["Algo"].replace("UEC Version A", "VersA")
    df["Algo"] = df["Algo"].replace("UEC Version D", "VersD")


    # Sort the DataFrame by "CompletionTime(us)"
    df.sort_values(by="CompletionTime(us)", inplace=True)

    df = df[df["Algo"] != "NDP"]
    df = df[df["Algo"] != "UEC BTS"]
    df = df[df["Algo"] != "STrack"]
    
    

    # Create a string combination of the other columns for x-axis
    df["X_Label"] = df[all_options].astype(str).agg(' '.join, axis=1)

    # Creating the bar plot manually, alternating colors for FastDrop==0 and FastDrop==1
    fig, ax = plt.subplots()

    # Get the unique values of X_Label
    x_labels_unique = df["X_Label"].unique()

    # Calculate the number of bars for each group (FastDrop=0 and FastDrop=1)
    num_bars_per_group = df[filtering_on].nunique()

    df.sort_values(by="X_Label", inplace=True)
    # Calculate the total width of each group of bars
    group_width = 0.8

    # Calculate the spacing between each pair of bars
    spacing = 0.1

    # Calculate the width of each bar within a group
    bar_width = (group_width - spacing) / num_bars_per_group

    plt.axhline(y=completion_time_ndp, color="red", linestyle="--", label="NDP")
    #plt.axhline(y=completion_time_bts, color="black", linestyle="--", label="BTS")
    #plt.axhline(y=completion_time_strack, color="green", linestyle="--", label="STrack")
    
    plt.axhline(y=completion_time_ndp + (completion_time_ndp * 0.05), color="grey", linestyle="-", label="+10")
    plt.axhline(y=completion_time_ndp - (completion_time_ndp * 0.1), color="grey", linestyle="-", label="-10")

    if (possible_value_3 is None):
        # Plot the bars for FastDrop == 0
        for idx, x_label in enumerate(x_labels_unique):
            df_subset = df[(df["X_Label"] == x_label) & (df[filtering_on] == possible_value_1)]  
            ax.bar([pos + idx * (group_width + spacing) for pos in range(len(df_subset))], df_subset["CompletionTime(us)"], width=bar_width, color="blue", label="{} == {}".format(filtering_on, possible_value_1) if idx == 0 else "")
        # Plot the bars for FastDrop == 1 with a small offset
        for idx, x_label in enumerate(x_labels_unique):
            df_subset = df[(df["X_Label"] == x_label) & (df[filtering_on] == possible_value_2)]
            ax.bar([pos + idx * (group_width + spacing) + bar_width for pos in range(len(df_subset))], df_subset["CompletionTime(us)"], width=bar_width, color="orange", label="{} == {}".format(filtering_on, possible_value_2) if idx == 0 else "")
    else:
        print("Ciao2")
        # Plot the bars for FastDrop == 0
        for idx, x_label in enumerate(x_labels_unique):
            df_subset = df[(df["X_Label"] == x_label) & (df[filtering_on] == possible_value_1)]
            ax.bar([pos + idx * (group_width + spacing) for pos in range(len(df_subset))], df_subset["CompletionTime(us)"], width=bar_width, color="blue", label="{} == {}".format(filtering_on, possible_value_1) if idx == 0 else "")
        # Plot the bars for FastDrop == 1 with a small offset
        for idx, x_label in enumerate(x_labels_unique):
            df_subset = df[(df["X_Label"] == x_label) & (df[filtering_on] == possible_value_2)]
            ax.bar([pos + idx * (group_width + spacing) + bar_width for pos in range(len(df_subset))], df_subset["CompletionTime(us)"], width=bar_width, color="orange", label="{} == {}".format(filtering_on, possible_value_2) if idx == 0 else "")
        # Plot the bars for FastDrop == 1 with a small offset
        for idx, x_label in enumerate(x_labels_unique):
            df_subset = df[(df["X_Label"] == x_label) & (df[filtering_on] == possible_value_3)]
            ax.bar([pos + idx * (group_width + spacing) + (bar_width * 2) for pos in range(len(df_subset))], df_subset["CompletionTime(us)"], width=bar_width, color="grey", label="{} == {}".format(filtering_on, possible_value_3) if idx == 0 else "")
        
    
    ax.legend()
    plt.ylim(lowest_completion_time - (lowest_completion_time * 0.05), max_completion_time + (max_completion_time * 0.05))
    plt.xlabel("Configuration (K = KMIn, FD = FastDrop, FI = FastIncrease, J = DoJitter, E = DoExpGain, D = DelayGainValue, FD = FastDrop)")
    plt.ylabel("Completion Time(us)")
    plt.title("Completion Time (us) comparing Feature: {} at {}".format(filtering_on, my_folder))

    # Set the x-axis tick positions and labels
    my_pos = []
    #print(len(x_labels_unique))
    for idx, x_label in enumerate(x_labels_unique):
        
        #print(len(df_subset))
        for pos in range(1):
            #print("My Len is {} - Accessing {}\n".format(len(my_pos), pos + idx * (group_width + spacing) + bar_width ))  
            my_pos.append(pos + idx * (group_width + spacing) + bar_width - (bar_width / 2))
        
        #my_pos.append([pos + idx * (group_width + spacing) + bar_width for pos in range(len(df_subset))][0] - (bar_width / 2))
    ax.set_xticks(my_pos)
    ax.set_xticklabels(x_labels_unique, rotation=90, ha='center')

    # Show the legend
    rcParams['figure.figsize'] = 25,10
    

    plt.tight_layout()
    plt.show()

# %%
# Input Values
df = pd.read_csv(my_folder + "/Summary.csv")
df = df[~((df["KMin"] == 20) & (df["DelayGain"] == 2))]
df = df[~((df["KMin"] == 50) & (df["DelayGain"] == 5))]
filtering_on = "FastDrop"
possible_value_0 = 0
possible_value_1 = 1

# More Filtering
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'STrack') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC BTS') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 1.0))]

print(len(df))
display(df)
# Generate Plot
run_comparison(df, filtering_on, possible_value_0, possible_value_1)
# Out:
# 23
#               Algo  KMin  KMax  TargetRTT  FastDrop  FastIncrease  DoJitter  \
# 1              NDP     0     0          0         0             0         0
# 2    UEC Version A    20    80         20         0             1         0
# 4    UEC Version A    20    80         20         0             1         0
# 5    UEC Version A    20    80         20         0             0         0
# 7    UEC Version A    20    80         20         0             0         0
# 14   UEC Version D    20    80         20         1             1         0
# 19   UEC Version A    50    80         50         0             1         0
# 20   UEC Version D    20    80         20         0             1         0
# 23   UEC Version D    20    80         20         0             0         0
# 26   UEC Version A    50    80         50         0             0         0
# 37   UEC Version D    50    80         50         1             0         0
# ...

# %%
# Input Values
df = pd.read_csv(my_folder + "/Summary.csv")
print(len(df))
df = df[~((df["KMin"] == 20) & (df["DelayGain"] == 2))]
df = df[~((df["KMin"] == 50) & (df["DelayGain"] == 5))]
print(len(df))
filtering_on = "KMin"
possible_value_0 = 20
possible_value_1 = 50

# Generate Plot
run_comparison(df, filtering_on, possible_value_0, possible_value_1)
# Out:
# 195
# 131

# %%
# Input Values
df = pd.read_csv(my_folder + "/Summary.csv")
df = df[~((df["KMin"] == 20) & (df["DelayGain"] == 2))]
df = df[~((df["KMin"] == 50) & (df["DelayGain"] == 5))]
filtering_on = "FastIncrease"
possible_value_0 = 0
possible_value_1 = 1

# Generate Plot
run_comparison(df, filtering_on, possible_value_0, possible_value_1)

# %%
# Input Values
df = pd.read_csv(my_folder + "/Summary.csv")
df = df[~((df["KMin"] == 20) & (df["FastDrop"] == 0)  & (df["FastIncrease"] == 0)  & (df["Algo"] == "UEC Version A")  & (df["DoExpGain"] == 0)  & (df["DelayGain"] == 0))]
df = df[~((df["KMin"] == 20) & (df["FastDrop"] == 0)  & (df["FastIncrease"] == 0)  & (df["Algo"] == "UEC Version A") & (df["DoJitter"] == 0)  & (df["DoExpGain"] == 0)  & (df["DelayGain"] == 0))]


df = df[~((df["KMin"] == 20) & (df["DelayGain"] == 2))]
df = df[~((df["KMin"] == 50) & (df["DelayGain"] == 5))]
filtering_on = "DoJitter"
possible_value_0 = 0
possible_value_1 = 1

# Generate Plot
run_comparison(df, filtering_on, possible_value_0, possible_value_1)

# %%
# Input Values
df = pd.read_csv(my_folder + "/Summary.csv")
'''
df = df[~((df["KMin"] == 20) & (df["FastDrop"] == 0)  & (df["FastIncrease"] == 0)  & (df["Algo"] == "UEC Version A")  & (df["DoExpGain"] == 0)  & (df["DelayGain"] == 0))]
df = df[~((df["KMin"] == 20) & (df["FastDrop"] == 0)  & (df["FastIncrease"] == 0)  & (df["Algo"] == "UEC Version A") & (df["DoJitter"] == 0)  & (df["DoExpGain"] == 0)  & (df["DelayGain"] == 0))]
df = df[~((df["KMin"] == 50) & (df["FastDrop"] == 0)  & (df["FastIncrease"] == 0)  & (df["Algo"] == "UEC Version A") & (df["DoJitter"] == 1)  & (df["DoExpGain"] == 0)  & (df["DelayGain"] == 0))]
df = df[~((df["KMin"] == 50) & (df["FastDrop"] == 0)  & (df["FastIncrease"] == 0)  & (df["Algo"] == "UEC Version A") & (df["DoJitter"] == 0)  & (df["DoExpGain"] == 0)  & (df["DelayGain"] == 0))]


df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]

df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]

df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]

df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'STrack') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]


# 5% threshold
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]

df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]

df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]

df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 1)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 2.0))]

df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 1)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 1.0))]

df = df[~((df['KMin'] == 50) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 1)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 0)  & (df['Algo'] == 'UEC Version D') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 5.0))]
df = df[~((df['KMin'] == 20) & (df['FastDrop'] == 0)  & (df['FastIncrease'] == 1)  & (df['Algo'] == 'UEC Version A') & (df['DoJitter'] == 0)  & (df['DoExpGain'] == 0)  & (df['DelayGain'] == 0.0))]
'''
df = df[~((df["KMin"] == 20) & (df["DelayGain"] == 2))]
df = df[~((df["KMin"] == 50) & (df["DelayGain"] == 5))]
filtering_on = "DoExpGain"
possible_value_0 = 0
possible_value_1 = 1

# Generate Plot
run_comparison(df, filtering_on, possible_value_0, possible_value_1)

# %%
# Input Values
df = pd.read_csv(my_folder + "/Summary.csv")
df = df[~((df["KMin"] == 20) & (df["DelayGain"] == 2))]
df = df[~((df["KMin"] == 50) & (df["DelayGain"] == 5))]
filtering_on = "Algo"
possible_value_0 = "VersA"
possible_value_1 = "VersD"

# Generate Plot
run_comparison(df, filtering_on, possible_value_0, possible_value_1)

# %%
# Input Values
df = pd.read_csv(my_folder + "/Summary.csv")
df = df[~((df["KMin"] == 20) & (df["DelayGain"] == 2))]
df = df[~((df["KMin"] == 50) & (df["DelayGain"] == 5))]
filtering_on = "DelayGain"
possible_value_0 = 0
possible_value_1 = 2
possible_value_2 = 5

# Generate Plot
run_comparison(df, filtering_on, possible_value_0, possible_value_1, possible_value_2)
